# %% [markdown]
# Задание 1.1¶
#
# Загрузите таблицу из файла data.csv в переменную df типа pd.DataFrame. В качестве индекса следует использовать колонку PassengerId.

# %%
import pandas as pd
df = pd.read_csv('data.csv', sep=';', index_col='PassengerId')

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
with open('data.csv', 'r') as datafile:
    data_lines = datafile.read().splitlines() #открываем файл и читаем его содержимое

# %%
print data_lines[0] #читаем все заголовки
# Out:
# PassengerId;Survived;Pclass;Name;Sex;Age;SibSp;Parch;Ticket;Fare;Cabin;Embarked

# %% [markdown]
# Задание 1.2
#
# Сколько строк и столбцов в таблице?

# %%
df.shape #узнаем размер таблицы
# Out:
# (891, 11)

# %%
print df.columns #список столбцов
# Out:
# Index([u'Survived', u'Pclass', u'Name', u'Sex', u'Age', u'SibSp', u'Parch',
#        u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')

# %% [markdown]
# Задание 1.3
#
# Выведите на экран последние три значения столбца Age(возраст).

# %%
#df['Age'][::-3] #разворот значений
#df.loc[[891,890,889],'Age'] #поиск по id в столбце id и згачения в столбце возраст
df.iloc[-3:,-7] #-3 определяет число id с конца, вторая цифра столбец
# Out:
# PassengerId
# 889     NaN
# 890    26.0
# 891    32.0
# Name: Age, dtype: float64

# %% [markdown]
# Задание 1.4
# Какова доля выживших (поле Survived)? поле в котором указано спасся человек (1) или нет (0)

# %%
#df.Pclass.count()#сколько значений в столбце
df.Survived.value_counts()/df.Pclass.count()
#cчитает число раз повторений 0 и 1. делим на число записей
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
t = df.Survived.sum()
print unicode("Доля выживших", encoding='utf-8'), t/891.0
# Out:
# Доля выживших 0.383838383838

# %% [markdown]
# Задание 1.5
#
# Выведите на экран таблицу, отсортированную по имени по алфавиту (поле Name).

# %%
pd.set_option('display.max_rows', 9) #сколько выводить на экран строк
pd.set_option('display.max_columns', 15)#сколько выводить на экран столбцов
t= df.sort_values('Name')
t
#t.to_csv('train_head.csv', sep=';')#записывает в новую таблицу
# Out:
#              Survived  Pclass                              Name     Sex   Age  \
# PassengerId
# 846                 0       3               Abbing, Mr. Anthony    male  42.0
# 747                 0       3       Abbott, Mr. Rossmore Edward    male  16.0
# 280                 1       3  Abbott, Mrs. Stanton (Rosa Hunt)  female  35.0
# 309                 0       2               Abelson, Mr. Samuel    male  30.0
# ...               ...     ...                               ...     ...   ...
# 283                 0       3         de Pelsmaeker, Mr. Alfons    male  16.0
# 362                 0       2         del Carlo, Mr. Sebastiano    male  29.0
# 154                 0       3   van Billiard, Mr. Austin Blyler    male  40.5
# 869                 0       3       van Melkebeke, Mr. Philemon    male   NaN
#
#              SibSp  Parch         Ticket     Fare Cabin Embarked
# PassengerId
# 846              0      0      C.A. 5547   7.5500   NaN        S
# ...

# %% [markdown]
# Задание 1.6¶
#
# Каковы доли женщин и мужчин среди пассажиров (поле Sex)?

# %%
#df.Pclass.count()
df.Sex.value_counts()/df.Pclass.count()
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %% [markdown]
# Задание 2.1¶
#
# Каков процент женщин и мужчин среди пассажиров? (Hint: процент – это доля, умноженная на 100.)

# %%
t =df.Sex.value_counts()/df.Pclass.count()

# %%
t*100
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64

# %% [markdown]
# Задание 2.2¶
#
# Какова доля совершеннолетних пассажиров (18 лет и старше)?

# %%
t = df[df['Age']>18]
t['Age2'] = 0
t.Age2.value_counts()/df.Pclass.count()

#t.Age.value_counts()
# Out:
# D:\USERS\agzinche\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# 0    0.645342
# Name: Age2, dtype: float64

# %% [markdown]
# Задание 2.3¶
#
# Замените коды пассажирских классов (поле Pclass) их названиями (1 = Upper, 2 = Middle, 3 = Lower). Результат выведите на экран.

# %%
df.replace({'Pclass':{1:'Upper', 2 : 'Middle', 3 : 'Lower'}})
# Out:
#              Survived Pclass  \
# PassengerId
# 1                   0  Lower
# 2                   1  Upper
# 3                   1  Lower
# 4                   1  Upper
# ...               ...    ...
# 888                 1  Upper
# 889                 0  Lower
# 890                 1  Upper
# 891                 0  Lower
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# ...                                                        ...     ...   ...
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# ...

# %% [markdown]
# Задача 2.4¶
#
# Какова доля выживших среди женщин? Среди мужчин?

# %%
t = df[df['Survived']==1]
t.Sex.value_counts()/t.Pclass.count()
#t.to_csv('train_head11.csv', sep=';')
# Out:
# female    0.681287
# male      0.318713
# Name: Sex, dtype: float64

# %% [markdown]
# Задача 2.5¶
#
# Сколько всего пропущенных значений в таблице?

# %%
df.info()#fillna(-1000)если нужно заменить значения пустые на число
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# Задание 3.1¶
#
# Добавьте в таблицу поле Surname – фамилию пассажира.

# %%
#df['Surname'] = df.Name
df['Surname']=df['Name'].str.split(',').str.get(0)
#строку в столбце делим и передаеь 0 значение
df [['Surname']]
# Out:
#                Surname
# PassengerId
# 1               Braund
# 2              Cumings
# 3            Heikkinen
# 4             Futrelle
# ...                ...
# 888             Graham
# 889           Johnston
# 890               Behr
# 891             Dooley
#
# [891 rows x 1 columns]

# %% [markdown]
# Задание 3.2
#
# Найдите всех пассажиров с аномальной стоимостью билета (поле Fare). Будем считать стоимость аномальной, если она отличается от среднего более, чем на 5 стандартных отклонений. Выведите соответствующие строки таблицы на экран.

# %%
t= df.Fare.mean()
t +5
# Out:
# 37.2042079685746
